# %% [markdown]
# # Mongo tutorial

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ### Server status
#
# Check the status of your Mongo cluster : `!sudo service mongodb status`
#
# If the cluster is inactive, `!sudo service mongodb start` to start it.

# %%
# !sudo service mongodb status
# Out:
# 489.67s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# [sudo] password for serendipita:

# %% [markdown]
# ### Import libraries

# %%
import datetime
from pprint import pprint

import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)

# %%
# let's work in a test_database
db = client.test_database
posts = db.posts
users = db.users

# %%
post = {
    "author": "Mike",
    "text": "My first blog post!",
    "tags": ["mongodb", "python", "pymongo"],
    "date": datetime.datetime.utcnow()
}
post_id = posts.insert_one(post).inserted_id
post_id
# Out:
# ObjectId('631c5637c42f03d63340ccef')

# %%
db.list_collection_names()
# Out:
# ['posts']

# %%
pprint(posts.find_one())
# Out:
# {'_id': ObjectId('631c5637c42f03d63340ccef'),
#  'author': 'Mike',
#  'date': datetime.datetime(2022, 9, 10, 9, 17, 43, 215000),
#  'tags': ['mongodb', 'python', 'pymongo'],
#  'text': 'My first blog post!'}

# %% [markdown]
# You can launch a terminal aside, connect to your server with a mongo client and check that the value is present :
#
# ```bash
# vagrant@nosql:~$ mongo
# > show databases;
# admin          0.000GB
# config         0.000GB
# local          0.000GB
# test_database  0.000GB
# > use test_database;
# switched to db test_database
# > db.posts.find()
# {
#     "_id" : ObjectId("..."),
#     "author" : "Mike",
#     "text" : "My first blog post!",
#     "tags" : [ "mongodb", "python", "pymongo"],
#     "date" : ISODate("2019-02-10T11:33:47.883Z")
# }
# ```

# %% [markdown]
# ## I. Quick start

# %% [markdown]
# ### First steps

# %% [markdown]
# **Q** : Create a document `{msg: 'hello'}` in the `test` collection with `insert_one()`. Fetch it back to display it. What is the `_id` for ?
#
# NB : if the collection doesn't exist yet, MongoDB automatically creates it.

# %%
#db = client.test_database
tests = db.test
test = {
    "msg": "hello",
    "date": datetime.datetime.utcnow()
}
test_id = tests.insert_one(test).inserted_id
test_id
# Out:
# ObjectId('631c5637c42f03d63340ccf0')

# %% [markdown]
# **Q**: Display the number of documents inside the `test` collection

# %%
db.list_collection_names()
pprint(tests.find_one())
# Out:
# {'_id': ObjectId('631c5637c42f03d63340ccf0'),
#  'date': datetime.datetime(2022, 9, 10, 9, 17, 43, 510000),
#  'msg': 'hello'}

# %% [markdown]
# ### Interacting with a database
#
# We have 2 `.json` files we want to interact with inside the `data` folder. Let's first dump them into a `MovieLens` database, inside `users` and `movies` collections.
#
# For this section, you will need to read a bit on [query operators](https://docs.mongodb.com/manual/reference/operator/query/#query-selectors). Most methods on collections you will use have `filter` as a first parameter, on which you must pass a dictionary of query parameters.

# %% [markdown]
# **Q** : In the `MovieLens` database, load `data/movielens_movies.json` into `movies` and `data/movielens_users.json` into `users`.
#
# Use the dedicated shell command for this : `mongoimport --db <some_db> --collection <some_collection> --file <some_file>`

# %%
#!sudo su

# %%
# !mongoimport --db MovieLens --collection movies --file ../datasets/json/movielens_movies.json
# Out:
# 2022-09-10T04:17:43.881-0500	connected to: mongodb://localhost/
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 2 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 10 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 12 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 13 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 14 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 16 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 15 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 17 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 18 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 21 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 19 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 22 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 20 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 23 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 24 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 25 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 8 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 5 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 29 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 9 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 28 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 11 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 1 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 7 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 6 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 26 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 27 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 30 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 31 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 4 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 32 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 33 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 34 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 35 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 36 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 37 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 38 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 40 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 39 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 41 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 42 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 43 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 45 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 44 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 48 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 46 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 47 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 49 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 51 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 50 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 52 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 53 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 55 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 54 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 56 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 58 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 57 }
# 2022-09-10T04:17:43.970-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 60 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 61 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 59 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 66 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 73 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 75 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 63 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 77 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 74 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 76 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 78 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 79 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 72 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 81 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 80 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 82 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 83 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 84 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 85 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 88 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 87 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 86 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 67 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 89 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 90 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 69 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 70 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 71 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 68 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 65 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 64 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 62 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 93 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 94 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 92 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 96 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 97 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 95 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 98 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 99 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 100 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 102 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 101 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 103 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 104 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 106 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 105 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 108 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 109 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 107 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 110 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 112 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 111 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 114 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 113 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 117 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 120 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 127 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 126 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 128 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 129 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 130 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 131 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 132 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 133 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 135 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 134 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 137 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 136 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 125 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 139 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 138 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 142 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 140 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 143 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 141 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 122 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 118 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 119 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 115 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 121 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 124 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 116 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 123 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 145 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 144 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 147 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 146 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 149 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 148 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 151 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 150 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 152 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 153 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 155 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 154 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 156 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 157 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 158 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 159 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 160 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 161 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 162 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 163 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 164 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 165 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 168 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 167 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 166 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 169 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 170 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 172 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 171 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 173 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 174 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 175 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 176 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 188 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 187 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 189 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 190 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 191 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 192 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 193 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 194 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 195 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 196 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 198 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 181 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 197 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 200 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 199 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 201 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 177 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 178 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 203 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 179 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 202 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 180 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 184 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 204 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 185 }
# 2022-09-10T04:17:43.971-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 182 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 186 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 183 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 208 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 217 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 216 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 218 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 219 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 220 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 222 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 223 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 224 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 226 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 225 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 227 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 228 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 229 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 230 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 231 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 233 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 234 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 209 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 232 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 210 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 205 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 206 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 211 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 207 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 212 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 213 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 214 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 215 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 235 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 236 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 237 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 238 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 239 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 240 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 241 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 242 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 244 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 243 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 246 }
# 2022-09-10T04:17:43.972-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 247 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 245 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 248 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 253 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 261 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 260 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 262 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 263 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 265 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 266 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 264 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 267 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 269 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 268 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 270 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 271 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 272 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 273 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 274 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 275 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 277 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 276 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 278 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 279 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 280 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 281 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 282 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 283 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 285 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 284 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 286 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 288 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 287 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 289 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 290 }
# 2022-09-10T04:17:43.973-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 249 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 250 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 251 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 254 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 252 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 255 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 258 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 259 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 256 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 257 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 293 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 291 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 304 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 305 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 306 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 307 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 308 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 309 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 310 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 311 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 303 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 312 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 314 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 313 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 315 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 316 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 317 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 318 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 319 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 320 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 294 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 295 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 292 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 296 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 297 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 298 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 321 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 322 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 324 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 325 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 326 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 327 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 328 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 330 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 329 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 331 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 332 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 334 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 333 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 301 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 299 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 300 }
# 2022-09-10T04:17:43.974-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 302 }
# ...
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3846 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3847 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3848 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3845 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3850 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3852 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3851 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3849 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3853 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3855 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3856 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3857 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3854 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3859 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3858 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3860 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3862 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3861 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3863 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3864 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3865 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3868 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3876 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3878 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3877 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3880 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3879 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3881 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3882 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3885 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3884 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3886 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3883 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3888 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3872 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3889 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3890 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3874 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3891 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3894 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3893 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3887 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3895 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3873 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3867 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3869 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3866 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3870 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3871 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3875 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3892 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3896 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3897 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3898 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3899 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3900 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3901 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3903 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3904 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3902 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3905 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3907 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3908 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3906 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3909 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3910 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3914 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3911 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3922 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3921 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3923 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3925 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3924 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3927 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3926 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3917 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3915 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3912 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3916 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3913 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3918 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3928 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3919 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3920 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3929 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3930 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3932 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3931 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3933 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3937 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3935 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3936 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3938 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3934 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3939 }
# 2022-09-10T04:17:44.291-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3940 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3941 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3944 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3943 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3945 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3942 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3949 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3946 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3947 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3951 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3948 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3952 }
# 2022-09-10T04:17:44.293-0500	continuing through error: E11000 duplicate key error collection: MovieLens.movies index: _id_ dup key: { _id: 3950 }
# 2022-09-10T04:17:44.293-0500	0 document(s) imported successfully. 3883 document(s) failed to import.

# %%
# !mongoimport --db MovieLens --collection users --file ../datasets/json/movielens_users.json
# Out:
# 2022-09-10T04:17:44.504-0500	connected to: mongodb://localhost/
# 2022-09-10T04:17:46.641-0500	6040 document(s) imported successfully. 0 document(s) failed to import.

# %% [markdown]
# **Q** : how many users are in the `MovieLens` database ?

# %%
db = client.MovieLens
users = db.users
users.count_documents({})

movies = db.movies
movies.count_documents({})
# Out:
# 3883

# %% [markdown]
# **Q** : Display all comedies (the `genres` property equals `Comedy`).
#
# NB : You will need to find how to go through a `command_cursor`, then use the `pprint` function for a better display of those documents.

# %%
movies = db.movies
# movies.find()
for movie in movies.find():
    if movie["genres"] == "Comedy":
        pprint(movie)
# Out:
# {'_id': 19,
#  'genres': 'Comedy',
#  'title': 'Ace Ventura: When Nature Calls (1995)'}
# {'_id': 38, 'genres': 'Comedy', 'title': 'It Takes Two (1995)'}
# {'_id': 5, 'genres': 'Comedy', 'title': 'Father of the Bride Part II (1995)'}
# {'_id': 52, 'genres': 'Comedy', 'title': 'Mighty Aphrodite (1995)'}
# {'_id': 63,
#  'genres': 'Comedy',
#  'title': "Don't Be a Menace to South Central While Drinking Your Juice in the "
#           'Hood (1996)'}
# {'_id': 65, 'genres': 'Comedy', 'title': 'Bio-Dome (1996)'}
# {'_id': 69, 'genres': 'Comedy', 'title': 'Friday (1995)'}
# {'_id': 88, 'genres': 'Comedy', 'title': 'Black Sheep (1996)'}
# {'_id': 96, 'genres': 'Comedy', 'title': 'In the Bleak Midwinter (1995)'}
# {'_id': 104, 'genres': 'Comedy', 'title': 'Happy Gilmore (1996)'}
# {'_id': 109, 'genres': 'Comedy', 'title': 'Headless Body in Topless Bar (1995)'}
# {'_id': 115, 'genres': 'Comedy', 'title': 'Happiness Is in the Field (1995)'}
# {'_id': 119, 'genres': 'Comedy', 'title': 'Steal Big, Steal Little (1995)'}
# {'_id': 101, 'genres': 'Comedy', 'title': 'Bottle Rocket (1996)'}
# {'_id': 102, 'genres': 'Comedy', 'title': 'Mr. Wrong (1996)'}
# {'_id': 125, 'genres': 'Comedy', 'title': 'Flirting With Disaster (1996)'}
# {'_id': 135, 'genres': 'Comedy', 'title': 'Down Periscope (1996)'}
# {'_id': 141, 'genres': 'Comedy', 'title': 'Birdcage, The (1996)'}
# {'_id': 144, 'genres': 'Comedy', 'title': 'Brothers McMullen, The (1995)'}
# {'_id': 156, 'genres': 'Comedy', 'title': 'Blue in the Face (1995)'}
# {'_id': 174, 'genres': 'Comedy', 'title': 'Jury Duty (1995)'}
# {'_id': 171, 'genres': 'Comedy', 'title': 'Jeffrey (1995)'}
# {'_id': 176, 'genres': 'Comedy', 'title': 'Living in Oblivion (1995)'}
# {'_id': 178, 'genres': 'Comedy', 'title': 'Love & Human Remains (1993)'}
# {'_id': 180, 'genres': 'Comedy', 'title': 'Mallrats (1995)'}
# {'_id': 186, 'genres': 'Comedy', 'title': 'Nine Months (1995)'}
# {'_id': 187, 'genres': 'Comedy', 'title': 'Party Girl (1995)'}
# {'_id': 189, 'genres': 'Comedy', 'title': 'Reckless (1995)'}
# {'_id': 203,
#  'genres': 'Comedy',
#  'title': 'To Wong Foo, Thanks for Everything! Julie Newmar (1995)'}
# {'_id': 223, 'genres': 'Comedy', 'title': 'Clerks (1994)'}
# {'_id': 228, 'genres': 'Comedy', 'title': 'Destiny Turns on the Radio (1995)'}
# {'_id': 231, 'genres': 'Comedy', 'title': 'Dumb & Dumber (1994)'}
# {'_id': 234, 'genres': 'Comedy', 'title': 'Exit to Eden (1994)'}
# {'_id': 212, 'genres': 'Comedy', 'title': 'Bushwhacked (1995)'}
# {'_id': 216, 'genres': 'Comedy', 'title': 'Billy Madison (1995)'}
# {'_id': 243, 'genres': 'Comedy', 'title': 'Gordy (1995)'}
# {'_id': 248, 'genres': 'Comedy', 'title': 'Houseguest (1994)'}
# {'_id': 267, 'genres': 'Comedy', 'title': 'Major Payne (1994)'}
# {'_id': 255, 'genres': 'Comedy', 'title': 'Jerky Boys, The (1994)'}
# {'_id': 274, 'genres': 'Comedy', 'title': 'Man of the House (1995)'}
# {'_id': 275, 'genres': 'Comedy', 'title': 'Mixed Nuts (1994)'}
# {'_id': 278, 'genres': 'Comedy', 'title': 'Miami Rhapsody (1995)'}
# {'_id': 305,
#  'genres': 'Comedy',
#  'title': 'Ready to Wear (Pret-A-Porter) (1994)'}
# {'_id': 310, 'genres': 'Comedy', 'title': 'Rent-a-Kid (1995)'}
# {'_id': 312, 'genres': 'Comedy', 'title': 'Stuart Saves His Family (1995)'}
# {'_id': 298, 'genres': 'Comedy', 'title': 'Pushing Hands (1992)'}
# {'_id': 325,
#  'genres': 'Comedy',
#  'title': "National Lampoon's Senior Trip (1995)"}
# {'_id': 333, 'genres': 'Comedy', 'title': 'Tommy Boy (1995)'}
# {'_id': 324, 'genres': 'Comedy', 'title': 'Sum of Us, The (1994)'}
# {'_id': 348, 'genres': 'Comedy', 'title': 'Bullets Over Broadway (1994)'}
# {'_id': 344, 'genres': 'Comedy', 'title': 'Ace Ventura: Pet Detective (1994)'}
# {'_id': 352, 'genres': 'Comedy', 'title': 'Crooklyn (1994)'}
# {'_id': 370,
#  'genres': 'Comedy',
#  'title': 'Naked Gun 33 1/3: The Final Insult (1994)'}
# {'_id': 402, 'genres': 'Comedy', 'title': 'Open Season (1996)'}
# {'_id': 411, 'genres': 'Comedy', 'title': 'You So Crazy (1994)'}
# {'_id': 410, 'genres': 'Comedy', 'title': 'Addams Family Values (1993)'}
# {'_id': 413, 'genres': 'Comedy', 'title': 'Airheads (1994)'}
# {'_id': 429, 'genres': 'Comedy', 'title': 'Cabin Boy (1994)'}
# {'_id': 433, 'genres': 'Comedy', 'title': 'Clean Slate (1994)'}
# {'_id': 419, 'genres': 'Comedy', 'title': 'Beverly Hillbillies, The (1993)'}
# {'_id': 437, 'genres': 'Comedy', 'title': 'Cops and Robbersons (1994)'}
# {'_id': 445, 'genres': 'Comedy', 'title': 'Fatal Instinct (1993)'}
# {'_id': 441, 'genres': 'Comedy', 'title': 'Dazed and Confused (1993)'}
# {'_id': 414, 'genres': 'Comedy', 'title': 'Air Up There, The (1994)'}
# {'_id': 449, 'genres': 'Comedy', 'title': 'Fear of a Black Hat (1993)'}
# {'_id': 460, 'genres': 'Comedy', 'title': 'Getting Even with Dad (1994)'}
# {'_id': 467, 'genres': 'Comedy', 'title': 'Live Nude Girls (1995)'}
# {'_id': 470, 'genres': 'Comedy', 'title': 'House Party 3 (1994)'}
# {'_id': 453, 'genres': 'Comedy', 'title': 'For Love or Money (1993)'}
# {'_id': 478, 'genres': 'Comedy', 'title': 'Jimmy Hollywood (1994)'}
# {'_id': 486, 'genres': 'Comedy', 'title': 'Life with Mikey (1993)'}
# {'_id': 489, 'genres': 'Comedy', 'title': 'Made in America (1993)'}
# {'_id': 500, 'genres': 'Comedy', 'title': 'Mrs. Doubtfire (1993)'}
# {'_id': 505, 'genres': 'Comedy', 'title': 'North (1994)'}
# {'_id': 514, 'genres': 'Comedy', 'title': 'Ref, The (1994)'}
# {'_id': 518, 'genres': 'Comedy', 'title': 'Road to Wellville, The (1994)'}
# {'_id': 520, 'genres': 'Comedy', 'title': 'Robin Hood: Men in Tights (1993)'}
# {'_id': 542, 'genres': 'Comedy', 'title': 'Son in Law (1993)'}
# {'_id': 559, 'genres': 'Comedy', 'title': 'Paris, France (1993)'}
# {'_id': 564, 'genres': 'Comedy', 'title': 'Chasers (1994)'}
# {'_id': 585, 'genres': 'Comedy', 'title': 'Brady Bunch Movie, The (1995)'}
# {'_id': 582, 'genres': 'Comedy', 'title': 'Metisse (Caf� au Lait) (1993)'}
# {'_id': 598, 'genres': 'Comedy', 'title': 'Window to Paris (1994)'}
# {'_id': 576, 'genres': 'Comedy', 'title': 'Fausto (1993)'}
# {'_id': 603, 'genres': 'Comedy', 'title': 'Bye Bye, Love (1995)'}
# {'_id': 612, 'genres': 'Comedy', 'title': 'Pallbearer, The (1996)'}
# {'_id': 633, 'genres': 'Comedy', 'title': 'Denise Calls Up (1995)'}
# {'_id': 634, 'genres': 'Comedy', 'title': 'Theodore Rex (1995)'}
# {'_id': 637, 'genres': 'Comedy', 'title': 'Sgt. Bilko (1996)'}
# {'_id': 639, 'genres': 'Comedy', 'title': 'Girl 6 (1996)'}
# {'_id': 641,
#  'genres': 'Comedy',
#  'title': 'Little Indian, Big City (Un indien dans la ville) (1994)'}
# {'_id': 643,
#  'genres': 'Comedy',
#  'title': 'Peanuts - Die Bank zahlt alles (1996)'}
# {'_id': 619, 'genres': 'Comedy', 'title': 'Ed (1996)'}
# {'_id': 626,
#  'genres': 'Comedy',
#  'title': 'Thin Line Between Love and Hate, A (1996)'}
# {'_id': 644, 'genres': 'Comedy', 'title': 'Happy Weekend (1996)'}
# {'_id': 651, 'genres': 'Comedy', 'title': 'Superweib, Das (1996)'}
# {'_id': 655, 'genres': 'Comedy', 'title': 'Mutters Courage (1995)'}
# {'_id': 656, 'genres': 'Comedy', 'title': 'Eddie (1996)'}
# {'_id': 664, 'genres': 'Comedy', 'title': 'Faithful (1996)'}
# {'_id': 663,
#  'genres': 'Comedy',
#  'title': 'Kids in the Hall: Brain Candy (1996)'}
# {'_id': 700, 'genres': 'Comedy', 'title': 'Angus (1995)'}
# {'_id': 705, 'genres': 'Comedy', 'title': 'Cosi (1996)'}
# {'_id': 710, 'genres': 'Comedy', 'title': 'Celtic Pride (1996)'}
# {'_id': 725, 'genres': 'Comedy', 'title': 'Great White Hype, The (1996)'}
# {'_id': 728, 'genres': 'Comedy', 'title': 'Cold Comfort Farm (1995)'}
# {'_id': 719, 'genres': 'Comedy', 'title': 'Multiplicity (1996)'}
# {'_id': 717, 'genres': 'Comedy', 'title': 'Mouth to Mouth (Boca a boca) (1995)'}
# {'_id': 734, 'genres': 'Comedy', 'title': 'Getting Away With Murder (1996)'}
# {'_id': 739, 'genres': 'Comedy', 'title': 'Honigmond (1996)'}
# {'_id': 743, 'genres': 'Comedy', 'title': 'Spy Hard (1996)'}
# {'_id': 751, 'genres': 'Comedy', 'title': 'Careful (1992)'}
# {'_id': 747, 'genres': 'Comedy', 'title': 'Stupids, The (1996)'}
# {'_id': 772, 'genres': 'Comedy', 'title': 'Quartier Mozart (1992)'}
# {'_id': 785, 'genres': 'Comedy', 'title': 'Kingpin (1996)'}
# {'_id': 784, 'genres': 'Comedy', 'title': 'Cable Guy, The (1996)'}
# {'_id': 797,
#  'genres': 'Comedy',
#  'title': 'Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la '
#           'mer, La) (1991)'}
# {'_id': 811, 'genres': 'Comedy', 'title': 'Bewegte Mann, Der (1994)'}
# {'_id': 813, 'genres': 'Comedy', 'title': 'Larger Than Life (1996)'}
# {'_id': 818, 'genres': 'Comedy', 'title': 'Very Brady Sequel, A (1996)'}
# {'_id': 840, 'genres': 'Comedy', 'title': 'House Arrest (1996)'}
# {'_id': 834, 'genres': 'Comedy', 'title': 'Phat Beach (1996)'}
# {'_id': 833, 'genres': 'Comedy', 'title': 'High School High (1996)'}
# {'_id': 830, 'genres': 'Comedy', 'title': 'First Wives Club, The (1996)'}
# {'_id': 856, 'genres': 'Comedy', 'title': 'Mille bolle blu (1993)'}
# {'_id': 860,
#  'genres': 'Comedy',
#  'title': 'Maybe, Maybe Not (Bewegte Mann, Der) (1994)'}
# {'_id': 863, 'genres': 'Comedy', 'title': 'Celestial Clockwork (1994)'}
# {'_id': 868, 'genres': 'Comedy', 'title': 'Death in Brunswick (1991)'}
# {'_id': 870, 'genres': 'Comedy', 'title': "Gone Fishin' (1997)"}
# {'_id': 871, 'genres': 'Comedy', 'title': "Lover's Knot (1996)"}
# {'_id': 905, 'genres': 'Comedy', 'title': 'It Happened One Night (1934)'}
# {'_id': 921, 'genres': 'Comedy', 'title': 'My Favorite Year (1982)'}
# {'_id': 927, 'genres': 'Comedy', 'title': 'Women, The (1939)'}
# {'_id': 934, 'genres': 'Comedy', 'title': 'Father of the Bride (1950)'}
# {'_id': 947, 'genres': 'Comedy', 'title': 'My Man Godfrey (1936)'}
# {'_id': 951, 'genres': 'Comedy', 'title': 'His Girl Friday (1940)'}
# {'_id': 955, 'genres': 'Comedy', 'title': 'Bringing Up Baby (1938)'}
# {'_id': 1001, 'genres': 'Comedy', 'title': "Associate, The (L'Associe)(1982)"}
# {'_id': 1002, 'genres': 'Comedy', 'title': "Ed's Next Move (1996)"}
# {'_id': 1020, 'genres': 'Comedy', 'title': 'Cool Runnings (1993)'}
# {'_id': 1042, 'genres': 'Comedy', 'title': 'That Thing You Do! (1996)'}
# {'_id': 1075,
#  'genres': 'Comedy',
#  'title': 'Sexual Life of the Belgians, The (1994)'}
# {'_id': 1079, 'genres': 'Comedy', 'title': 'Fish Called Wanda, A (1988)'}
# {'_id': 1080,
#  'genres': 'Comedy',
#  'title': "Monty Python's Life of Brian (1979)"}
# {'_id': 1091, 'genres': 'Comedy', 'title': "Weekend at Bernie's (1989)"}
# {'_id': 1098,
#  'genres': 'Comedy',
#  'title': 'Search for One-eye Jimmy, The (1996)'}
# {'_id': 1107, 'genres': 'Comedy', 'title': 'Loser (1991)'}
# {'_id': 1113, 'genres': 'Comedy', 'title': 'Associate, The (1996)'}
# {'_id': 1135, 'genres': 'Comedy', 'title': 'Private Benjamin (1980)'}
# {'_id': 1136,
#  'genres': 'Comedy',
#  'title': 'Monty Python and the Holy Grail (1974)'}
# {'_id': 1143,
#  'genres': 'Comedy',
#  'title': 'Three Lives and Only One Death (1996)'}
# {'_id': 1125,
#  'genres': 'Comedy',
#  'title': 'Return of the Pink Panther, The (1974)'}
# {'_id': 1158, 'genres': 'Comedy', 'title': 'Here Comes Cookie (1935)'}
# {'_id': 1160, 'genres': 'Comedy', 'title': 'Six of a Kind (1934)'}
# {'_id': 1162, 'genres': 'Comedy', 'title': 'Ruling Class, The (1972)'}
# {'_id': 1166, 'genres': 'Comedy', 'title': 'Farmer & Chase (1995)'}
# {'_id': 1167, 'genres': 'Comedy', 'title': 'Dear God (1996)'}
# {'_id': 1171, 'genres': 'Comedy', 'title': 'Bob Roberts (1992)'}
# {'_id': 1174, 'genres': 'Comedy', 'title': 'Grosse Fatigue (1994)'}
# {'_id': 1180, 'genres': 'Comedy', 'title': 'Hear My Song (1991)'}
# {'_id': 1194, 'genres': 'Comedy', 'title': 'Up in Smoke (1978)'}
# {'_id': 1202, 'genres': 'Comedy', 'title': 'Withnail and I (1987)'}
# {'_id': 1235, 'genres': 'Comedy', 'title': 'Harold and Maude (1971)'}
# {'_id': 1238, 'genres': 'Comedy', 'title': 'Local Hero (1983)'}
# {'_id': 1257, 'genres': 'Comedy', 'title': 'Better Off Dead... (1985)'}
# {'_id': 1285, 'genres': 'Comedy', 'title': 'Heathers (1989)'}
# {'_id': 1281, 'genres': 'Comedy', 'title': 'Great Dictator, The (1940)'}
# {'_id': 1292, 'genres': 'Comedy', 'title': 'Being There (1979)'}
# {'_id': 1308, 'genres': 'Comedy', 'title': 'I Shot a Man in Vegas (1995)'}
# {'_id': 1311, 'genres': 'Comedy', 'title': 'Santa with Muscles (1996)'}
# {'_id': 1317, 'genres': 'Comedy', 'title': "I'm Not Rappaport (1996)"}
# {'_id': 1297, 'genres': 'Comedy', 'title': 'Real Genius (1985)'}
# {'_id': 1390, 'genres': 'Comedy', 'title': 'My Fellow Americans (1996)'}
# {'_id': 1394, 'genres': 'Comedy', 'title': 'Raising Arizona (1987)'}
# {'_id': 1414, 'genres': 'Comedy', 'title': 'Mother (1996)'}
# {'_id': 1425, 'genres': 'Comedy', 'title': 'Fierce Creatures (1997)'}
# {'_id': 1436, 'genres': 'Comedy', 'title': 'Falling in Love Again (1980)'}
# {'_id': 1439, 'genres': 'Comedy', 'title': 'Meet Wally Sparks (1997)'}
# {'_id': 1440, 'genres': 'Comedy', 'title': 'Amos & Andrew (1993)'}
# {'_id': 1454, 'genres': 'Comedy', 'title': 'SubUrbia (1997)'}
# {'_id': 1449, 'genres': 'Comedy', 'title': 'Waiting for Guffman (1996)'}
# {'_id': 1456, 'genres': 'Comedy', 'title': 'Pest, The (1997)'}
# {'_id': 1461, 'genres': 'Comedy', 'title': 'Vegas Vacation (1997)'}
# {'_id': 1446, 'genres': 'Comedy', 'title': 'Kolya (1996)'}
# {'_id': 1444, 'genres': 'Comedy', 'title': 'Guantanamera (1994)'}
# {'_id': 1494, 'genres': 'Comedy', 'title': 'Sixth Man, The (1997)'}
# {'_id': 1485, 'genres': 'Comedy', 'title': 'Liar Liar (1997)'}
# {'_id': 1503, 'genres': 'Comedy', 'title': '8 Heads in a Duffel Bag (1997)'}
# {'_id': 1511, 'genres': 'Comedy', 'title': 'A Chef in Love (1996)'}
# {'_id': 1516, 'genres': 'Comedy', 'title': 'Children of the Revolution (1996)'}
# {'_id': 1513,
#  'genres': 'Comedy',
#  'title': "Romy and Michele's High School Reunion (1997)"}
# {'_id': 1517,
#  'genres': 'Comedy',
#  'title': 'Austin Powers: International Man of Mystery (1997)'}
# {'_id': 1526, 'genres': 'Comedy', 'title': "Fathers' Day (1997)"}
# {'_id': 1528, 'genres': 'Comedy', 'title': 'Intimate Relations (1996)'}
# {'_id': 1532, 'genres': 'Comedy', 'title': 'Sprung (1997)'}
# {'_id': 1537,
#  'genres': 'Comedy',
#  'title': 'Shall We Dance? (Shall We Dansu?) (1996)'}
# {'_id': 1490, 'genres': 'Comedy', 'title': 'B*A*P*S (1997)'}
# {'_id': 1558, 'genres': 'Comedy', 'title': 'Sudden Manhattan (1996)'}
# {'_id': 1561, 'genres': 'Comedy', 'title': 'Wedding Bell Blues (1996)'}
# {'_id': 1546, 'genres': 'Comedy', 'title': 'Schizopolis (1996)'}
# {'_id': 1553, 'genres': 'Comedy', 'title': 'Late Bloomers (1996)'}
# {'_id': 1581, 'genres': 'Comedy', 'title': 'Out to Sea (1997)'}
# {'_id': 1585, 'genres': 'Comedy', 'title': 'Love Serenade (1996)'}
# {'_id': 1602, 'genres': 'Comedy', 'title': 'Leave It to Beaver (1997)'}
# {'_id': 1612, 'genres': 'Comedy', 'title': 'Kiss Me, Guido (1997)'}
# {'_id': 1614, 'genres': 'Comedy', 'title': 'In & Out (1997)'}
# {'_id': 1640, 'genres': 'Comedy', 'title': 'How to Be a Player (1997)'}
# {'_id': 1641, 'genres': 'Comedy', 'title': 'Full Monty, The (1997)'}
# {'_id': 1646, 'genres': 'Comedy', 'title': 'Rocket Man (1997)'}
# {'_id': 1663, 'genres': 'Comedy', 'title': 'Stripes (1981)'}
# {'_id': 1665, 'genres': 'Comedy', 'title': 'Bean (1997)'}
# {'_id': 1679, 'genres': 'Comedy', 'title': 'Chairman of the Board (1998)'}
# {'_id': 1677, 'genres': 'Comedy', 'title': 'Critical Care (1997)'}
# {'_id': 1698, 'genres': 'Comedy', 'title': 'Boys, Les (1997)'}
# {'_id': 1703, 'genres': 'Comedy', 'title': 'For Richer or Poorer (1997)'}
# {'_id': 1731, 'genres': 'Comedy', 'title': 'Mr. Magoo (1997)'}
# {'_id': 1738, 'genres': 'Comedy', 'title': 'Vermin (1998)'}
# {'_id': 1746, 'genres': 'Comedy', 'title': 'Senseless (1998)'}
# {'_id': 1753, 'genres': 'Comedy', 'title': 'Half Baked (1998)'}
# {'_id': 1793, 'genres': 'Comedy', 'title': 'Welcome to Woop-Woop (1997)'}
# {'_id': 1830, 'genres': 'Comedy', 'title': 'Follow the Bitch (1998)'}
# {'_id': 1837, 'genres': 'Comedy', 'title': 'Odd Couple II, The (1998)'}
# {'_id': 1839, 'genres': 'Comedy', 'title': 'My Giant (1998)'}
# {'_id': 1857, 'genres': 'Comedy', 'title': 'Real Blonde, The (1997)'}
# {'_id': 1863,
#  'genres': 'Comedy',
#  'title': 'Major League: Back to the Minors (1998)'}
# {'_id': 1864, 'genres': 'Comedy', 'title': 'Sour Grapes (1998)'}
# {'_id': 1875, 'genres': 'Comedy', 'title': 'Clockwatchers (1997)'}
# {'_id': 1853,
#  'genres': 'Comedy',
#  'title': 'Alan Smithee Film: Burn Hollywood Burn, An (1997)'}
# {'_id': 1855, 'genres': 'Comedy', 'title': "Krippendorf's Tribe (1998)"}
# {'_id': 1883, 'genres': 'Comedy', 'title': 'Bulworth (1998)'}
# {'_id': 1886, 'genres': 'Comedy', 'title': 'I Got the Hook Up (1998)'}
# {'_id': 1896, 'genres': 'Comedy', 'title': 'Cousin Bette (1998)'}
# {'_id': 1911, 'genres': 'Comedy', 'title': 'Doctor Dolittle (1998)'}
# {'_id': 1903, 'genres': 'Comedy', 'title': 'Hav Plenty (1997)'}
# {'_id': 1923,
#  'genres': 'Comedy',
#  'title': "There's Something About Mary (1998)"}
# {'_id': 1937, 'genres': 'Comedy', 'title': 'Going My Way (1944)'}
# {'_id': 1948, 'genres': 'Comedy', 'title': 'Tom Jones (1963)'}
# {'_id': 1934, 'genres': 'Comedy', 'title': "You Can't Take It With You (1938)"}
# {'_id': 1963, 'genres': 'Comedy', 'title': 'Take the Money and Run (1969)'}
# {'_id': 1966, 'genres': 'Comedy', 'title': 'Metropolitan (1990)'}
# {'_id': 2007, 'genres': 'Comedy', 'title': 'Polish Wedding (1998)'}
# {'_id': 2044, 'genres': 'Comedy', 'title': 'Devil and Max Devlin, The (1981)'}
# {'_id': 2060, 'genres': 'Comedy', 'title': 'BASEketball (1998)'}
# {'_id': 2072, 'genres': 'Comedy', 'title': "'burbs, The (1989)"}
# {'_id': 2073, 'genres': 'Comedy', 'title': 'Fandango (1985)'}
# {'_id': 2109, 'genres': 'Comedy', 'title': 'Jerk, The (1979)'}
# {'_id': 2111, 'genres': 'Comedy', 'title': 'Man with Two Brains, The (1983)'}
# {'_id': 2124, 'genres': 'Comedy', 'title': 'Addams Family, The (1991)'}
# {'_id': 2128, 'genres': 'Comedy', 'title': 'Safe Men (1998)'}
# {'_id': 2134, 'genres': 'Comedy', 'title': 'Weird Science (1985)'}
# {'_id': 2136, 'genres': 'Comedy', 'title': 'Nutty Professor, The (1963)'}
# {'_id': 2144, 'genres': 'Comedy', 'title': 'Sixteen Candles (1984)'}
# {'_id': 2150, 'genres': 'Comedy', 'title': 'Gods Must Be Crazy, The (1980)'}
# {'_id': 2151, 'genres': 'Comedy', 'title': 'Gods Must Be Crazy II, The (1989)'}
# {'_id': 2155, 'genres': 'Comedy', 'title': 'Slums of Beverly Hills, The (1998)'}
# {'_id': 2169, 'genres': 'Comedy', 'title': 'Dead Man on Campus (1998)'}
# {'_id': 2172,
#  'genres': 'Comedy',
#  'title': 'Strike! (a.k.a. All I Wanna Do, The Hairy Bird) (1998)'}
# {'_id': 2191, 'genres': 'Comedy', 'title': 'Merry War, A (1997)'}
# {'_id': 2195, 'genres': 'Comedy', 'title': 'Dirty Work (1998)'}
# {'_id': 2205, 'genres': 'Comedy', 'title': 'Mr. & Mrs. Smith (1941)'}
# {'_id': 2222, 'genres': 'Comedy', 'title': 'Champagne (1928)'}
# {'_id': 2223, 'genres': 'Comedy', 'title': "Farmer's Wife, The (1928)"}
# {'_id': 2230, 'genres': 'Comedy', 'title': 'Always Tell Your Wife (1923)'}
# {'_id': 2241, 'genres': 'Comedy', 'title': 'Class (1983)'}
# {'_id': 2247, 'genres': 'Comedy', 'title': 'Married to the Mob (1988)'}
# {'_id': 2246, 'genres': 'Comedy', 'title': 'Stars and Bars (1988)'}
# {'_id': 2249, 'genres': 'Comedy', 'title': 'My Blue Heaven (1990)'}
# {'_id': 2251, 'genres': 'Comedy', 'title': 'Cabinet of Dr. Ramirez, The (1991)'}
# {'_id': 2261, 'genres': 'Comedy', 'title': 'One Crazy Summer (1986)'}
# {'_id': 2255, 'genres': 'Comedy', 'title': 'Young Doctors in Love (1982)'}
# {'_id': 2286,
#  'genres': 'Comedy',
#  'title': 'Fiendish Plot of Dr. Fu Manchu, The (1980)'}
# {'_id': 2295, 'genres': 'Comedy', 'title': 'Impostors, The (1998)'}
# {'_id': 2299, 'genres': 'Comedy', 'title': 'Battle of the Sexes, The (1959)'}
# {'_id': 2301,
#  'genres': 'Comedy',
#  'title': 'History of the World: Part I (1981)'}
# {'_id': 2306, 'genres': 'Comedy', 'title': 'Holy Man (1998)'}
# {'_id': 2302, 'genres': 'Comedy', 'title': 'My Cousin Vinny (1992)'}
# {'_id': 2296, 'genres': 'Comedy', 'title': 'Night at the Roxbury, A (1998)'}
# {'_id': 2317, 'genres': 'Comedy', 'title': 'Alarmist, The (1997)'}
# {'_id': 2318, 'genres': 'Comedy', 'title': 'Happiness (1998)'}
# {'_id': 2319, 'genres': 'Comedy', 'title': 'Reach the Rock (1997)'}
# {'_id': 2321, 'genres': 'Comedy', 'title': 'Pleasantville (1998)'}
# {'_id': 2325, 'genres': 'Comedy', 'title': 'Orgazmo (1997)'}
# {'_id': 2335, 'genres': 'Comedy', 'title': 'Waterboy, The (1998)'}
# {'_id': 2342, 'genres': 'Comedy', 'title': 'Hard Core Logo (1996)'}
# {'_id': 2350, 'genres': 'Comedy', 'title': 'Heart Condition (1990)'}
# {'_id': 2356, 'genres': 'Comedy', 'title': 'Celebrity (1998)'}
# {'_id': 2361, 'genres': 'Comedy', 'title': 'Pink Flamingos (1972)'}
# {'_id': 2359, 'genres': 'Comedy', 'title': 'Waking Ned Devine (1998)'}
# {'_id': 2371, 'genres': 'Comedy', 'title': 'Fletch (1985)'}
# {'_id': 2372, 'genres': 'Comedy', 'title': 'Fletch Lives (1989)'}
# {'_id': 2375, 'genres': 'Comedy', 'title': 'Money Pit, The (1986)'}
# {'_id': 2378, 'genres': 'Comedy', 'title': 'Police Academy (1984)'}
# {'_id': 2379,
#  'genres': 'Comedy',
#  'title': 'Police Academy 2: Their First Assignment (1985)'}
# {'_id': 2381,
#  'genres': 'Comedy',
#  'title': 'Police Academy 4: Citizens on Patrol (1987)'}
# {'_id': 2383,
#  'genres': 'Comedy',
#  'title': 'Police Academy 6: City Under Siege (1989)'}
# {'_id': 2382,
#  'genres': 'Comedy',
#  'title': 'Police Academy 5: Assignment: Miami Beach (1988)'}
# {'_id': 2380,
#  'genres': 'Comedy',
#  'title': 'Police Academy 3: Back in Training (1986)'}
# {'_id': 2390, 'genres': 'Comedy', 'title': 'Little Voice (1998)'}
# {'_id': 2395, 'genres': 'Comedy', 'title': 'Rushmore (1998)'}
# {'_id': 2416, 'genres': 'Comedy', 'title': 'Back to School (1986)'}
# {'_id': 2418, 'genres': 'Comedy', 'title': 'Nothing in Common (1986)'}
# {'_id': 2423, 'genres': 'Comedy', 'title': 'Christmas Vacation (1989)'}
# {'_id': 2436, 'genres': 'Comedy', 'title': 'Tea with Mussolini (1999)'}
# {'_id': 2463, 'genres': 'Comedy', 'title': 'Ruthless People (1986)'}
# {'_id': 2472, 'genres': 'Comedy', 'title': 'Tough Guys (1986)'}
# {'_id': 2473, 'genres': 'Comedy', 'title': 'Soul Man (1986)'}
# {'_id': 2484, 'genres': 'Comedy', 'title': 'Tinseltown (1998)'}
# {'_id': 2492, 'genres': 'Comedy', 'title': '20 Dates (1998)'}
# {'_id': 2500, 'genres': 'Comedy', 'title': 'Jawbreaker (1999)'}
# {'_id': 2499, 'genres': 'Comedy', 'title': "God Said 'Ha!' (1998)"}
# {'_id': 2509, 'genres': 'Comedy', 'title': 'Eight Days a Week (1997)'}
# {'_id': 2507, 'genres': 'Comedy', 'title': 'Breakfast of Champions (1999)'}
# {'_id': 2518, 'genres': 'Comedy', 'title': 'Night Shift (1982)'}
# {'_id': 2539, 'genres': 'Comedy', 'title': 'Analyze This (1999)'}
# {'_id': 2543, 'genres': 'Comedy', 'title': 'Six Ways to Sunday (1997)'}
# {'_id': 2545, 'genres': 'Comedy', 'title': "Relax... It's Just Sex (1998)"}
# {'_id': 2552, 'genres': 'Comedy', 'title': "My Boyfriend's Back (1993)"}
# {'_id': 2555, 'genres': 'Comedy', 'title': 'Baby Geniuses (1999)'}
# {'_id': 2567, 'genres': 'Comedy', 'title': 'EDtv (1999)'}
# {'_id': 2574, 'genres': 'Comedy', 'title': 'Out-of-Towners, The (1999)'}
# {'_id': 2584, 'genres': 'Comedy', 'title': 'Foolish (1999)'}
# {'_id': 2587, 'genres': 'Comedy', 'title': 'Life (1999)'}
# {'_id': 2593, 'genres': 'Comedy', 'title': 'Monster, The (Il Mostro) (1994)'}
# {'_id': 2599, 'genres': 'Comedy', 'title': 'Election (1999)'}
# {'_id': 2598, 'genres': 'Comedy', 'title': 'Pushing Tin (1999)'}
# {'_id': 2601, 'genres': 'Comedy', 'title': 'Little Bit of Soul, A (1998)'}
# {'_id': 2623, 'genres': 'Comedy', 'title': "Trippin' (1999)"}
# {'_id': 2618, 'genres': 'Comedy', 'title': 'Castle, The (1997)'}
# {'_id': 2683,
#  'genres': 'Comedy',
#  'title': 'Austin Powers: The Spy Who Shagged Me (1999)'}
# {'_id': 2690, 'genres': 'Comedy', 'title': 'Ideal Husband, An (1999)'}
# {'_id': 2694, 'genres': 'Comedy', 'title': 'Big Daddy (1999)'}
# {'_id': 2696,
#  'genres': 'Comedy',
#  'title': 'Dinner Game, The (Le D�ner de cons) (1998)'}
# {'_id': 2706, 'genres': 'Comedy', 'title': 'American Pie (1999)'}
# {'_id': 2718, 'genres': 'Comedy', 'title': 'Drop Dead Gorgeous (1999)'}
# {'_id': 2736, 'genres': 'Comedy', 'title': 'Brighton Beach Memoirs (1986)'}
# {'_id': 2751, 'genres': 'Comedy', 'title': 'From the Hip (1987)'}
# {'_id': 2759, 'genres': 'Comedy', 'title': 'Dick (1999)'}
# {'_id': 2767, 'genres': 'Comedy', 'title': 'Illuminata (1998)'}
# {'_id': 2768, 'genres': 'Comedy', 'title': 'Stiff Upper Lips (1998)'}
# {'_id': 2770, 'genres': 'Comedy', 'title': 'Bowfinger (1999)'}
# {'_id': 2772, 'genres': 'Comedy', 'title': 'Detroit Rock City (1999)'}
# {'_id': 2779, 'genres': 'Comedy', 'title': 'Heaven Can Wait (1978)'}
# {'_id': 2786, 'genres': 'Comedy', 'title': 'Haunted Honeymoon (1986)'}
# {'_id': 2788,
#  'genres': 'Comedy',
#  'title': 'And Now for Something Completely Different (1971)'}
# {'_id': 2796, 'genres': 'Comedy', 'title': 'Funny Farm (1988)'}
# {'_id': 2792, 'genres': 'Comedy', 'title': 'Airplane II: The Sequel (1982)'}
# {'_id': 2798, 'genres': 'Comedy', 'title': 'Problem Child (1990)'}
# {'_id': 2799, 'genres': 'Comedy', 'title': 'Problem Child 2 (1991)'}
# {'_id': 2791, 'genres': 'Comedy', 'title': 'Airplane! (1980)'}
# {'_id': 2809, 'genres': 'Comedy', 'title': 'Love Stinks (1999)'}
# {'_id': 2811, 'genres': 'Comedy', 'title': 'With Friends Like These... (1998)'}
# {'_id': 2795, 'genres': 'Comedy', 'title': 'Vacation (1983)'}
# {'_id': 2794, 'genres': 'Comedy', 'title': 'European Vacation (1985)'}
# {'_id': 2838,
#  'genres': 'Comedy',
#  'title': 'I Woke Up Early the Day I Died (1998)'}
# {'_id': 2836, 'genres': 'Comedy', 'title': 'Outside Providence (1999)'}
# {'_id': 2864, 'genres': 'Comedy', 'title': 'Splendor (1999)'}
# {'_id': 2865, 'genres': 'Comedy', 'title': 'Sugar Town (1999)'}
# {'_id': 2870, 'genres': 'Comedy', 'title': 'Barefoot in the Park (1967)'}
# {'_id': 2860, 'genres': 'Comedy', 'title': 'Blue Streak (1999)'}
# {'_id': 2874, 'genres': 'Comedy', 'title': 'Pajama Game, The (1957)'}
# {'_id': 2883, 'genres': 'Comedy', 'title': 'Mumford (1999)'}
# {'_id': 2889, 'genres': 'Comedy', 'title': 'Mystery, Alaska (1999)'}
# {'_id': 2891, 'genres': 'Comedy', 'title': 'Happy, Texas (1999)'}
# {'_id': 2907, 'genres': 'Comedy', 'title': 'Superstar (1999)'}
# {'_id': 2913,
#  'genres': 'Comedy',
#  'title': 'Mating Habits of the Earthbound Human, The (1998)'}
# {'_id': 2915, 'genres': 'Comedy', 'title': 'Risky Business (1983)'}
# {'_id': 2918, 'genres': 'Comedy', 'title': "Ferris Bueller's Day Off (1986)"}
# {'_id': 2923,
#  'genres': 'Comedy',
#  'title': "Citizen's Band (a.k.a. Handle with Care) (1977)"}
# {'_id': 2937, 'genres': 'Comedy', 'title': 'Palm Beach Story, The (1942)'}
# {'_id': 2936, 'genres': 'Comedy', 'title': "Sullivan's Travels (1942)"}
# {'_id': 2973, 'genres': 'Comedy', 'title': 'Crimes and Misdemeanors (1989)'}
# {'_id': 2997, 'genres': 'Comedy', 'title': 'Being John Malkovich (1999)'}
# {'_id': 2999, 'genres': 'Comedy', 'title': 'Man of the Century (1999)'}
# {'_id': 3012, 'genres': 'Comedy', 'title': 'Battling Butler (1926)'}
# {'_id': 3014, 'genres': 'Comedy', 'title': "Bustin' Loose (1981)"}
# {'_id': 3022, 'genres': 'Comedy', 'title': 'General, The (1927)'}
# {'_id': 3028, 'genres': 'Comedy', 'title': 'Taming of the Shrew, The (1967)'}
# {'_id': 3031, 'genres': 'Comedy', 'title': 'Repossessed (1990)'}
# {'_id': 3040, 'genres': 'Comedy', 'title': 'Meatballs (1979)'}
# {'_id': 3039, 'genres': 'Comedy', 'title': 'Trading Places (1983)'}
# {'_id': 3041, 'genres': 'Comedy', 'title': 'Meatballs Part II (1984)'}
# {'_id': 3042, 'genres': 'Comedy', 'title': 'Meatballs III (1987)'}
# {'_id': 3043, 'genres': 'Comedy', 'title': 'Meatballs 4 (1992)'}
# {'_id': 3048, 'genres': 'Comedy', 'title': 'Under the Rainbow (1981)'}
# {'_id': 3052, 'genres': 'Comedy', 'title': 'Dogma (1999)'}
# {'_id': 3057, 'genres': 'Comedy', 'title': "Where's Marlowe? (1999)"}
# {'_id': 3072, 'genres': 'Comedy', 'title': 'Moonstruck (1987)'}
# {'_id': 3076, 'genres': 'Comedy', 'title': 'Irma la Douce (1963)'}
# {'_id': 3086,
#  'genres': 'Comedy',
#  'title': 'March of the Wooden Soldiers (a.k.a. Laurel & Hardy in Toyland) '
#           '(1934)'}
# {'_id': 3087, 'genres': 'Comedy', 'title': 'Scrooged (1988)'}
# {'_id': 3088, 'genres': 'Comedy', 'title': 'Harvey (1950)'}
# {'_id': 3096, 'genres': 'Comedy', 'title': 'My Man Godfrey (1957)'}
# {'_id': 3123,
#  'genres': 'Comedy',
#  'title': 'Spring Fever USA (a.k.a. Lauderdale) (1989)'}
# {'_id': 3130, 'genres': 'Comedy', 'title': 'Bonfire of the Vanities (1990)'}
# {'_id': 3131, 'genres': 'Comedy', 'title': 'Broadway Damage (1997)'}
# {'_id': 3132, 'genres': 'Comedy', 'title': 'Daddy Long Legs (1919)'}
# {'_id': 3133, 'genres': 'Comedy', 'title': 'Go West (1925)'}
# {'_id': 3140, 'genres': 'Comedy', 'title': 'Three Ages, The (1923)'}
# {'_id': 3146, 'genres': 'Comedy', 'title': 'Deuce Bigalow: Male Gigolo (1999)'}
# {'_id': 3120,
#  'genres': 'Comedy',
#  'title': 'Distinguished Gentleman, The (1992)'}
# {'_id': 3177, 'genres': 'Comedy', 'title': 'Next Friday (1999)'}
# {'_id': 3189, 'genres': 'Comedy', 'title': 'My Dog Skip (1999)'}
# {'_id': 3210,
#  'genres': 'Comedy',
#  'title': 'Fast Times at Ridgemont High (1982)'}
# {'_id': 3228, 'genres': 'Comedy', 'title': 'Wirey Spindell (1999)'}
# {'_id': 3231, 'genres': 'Comedy', 'title': 'Saphead, The (1920)'}
# {'_id': 3232, 'genres': 'Comedy', 'title': 'Seven Chances (1925)'}
# {'_id': 3233, 'genres': 'Comedy', 'title': 'Smashing Time (1967)'}
# {'_id': 3234, 'genres': 'Comedy', 'title': 'Train Ride to Hollywood (1978)'}
# {'_id': 3235, 'genres': 'Comedy', 'title': 'Where the Buffalo Roam (1980)'}
# {'_id': 3239, 'genres': 'Comedy', 'title': "Isn't She Great? (2000)"}
# {'_id': 3240, 'genres': 'Comedy', 'title': 'Big Tease, The (1999)'}
# {'_id': 3241, 'genres': 'Comedy', 'title': 'Cup, The (Ph�rpa) (1999)'}
# {'_id': 3242, 'genres': 'Comedy', 'title': 'Santitos (1997)'}
# {'_id': 3243, 'genres': 'Comedy', 'title': 'Encino Man (1992)'}
# {'_id': 3248,
#  'genres': 'Comedy',
#  'title': 'Sister Act 2: Back in the Habit (1993)'}
# {'_id': 3253, 'genres': 'Comedy', 'title': "Wayne's World (1992)"}
# {'_id': 3254, 'genres': 'Comedy', 'title': "Wayne's World 2 (1993)"}
# {'_id': 3258, 'genres': 'Comedy', 'title': 'Death Becomes Her (1992)'}
# {'_id': 3263, 'genres': 'Comedy', 'title': "White Men Can't Jump (1992)"}
# {'_id': 3276, 'genres': 'Comedy', 'title': 'Gun Shy (2000)'}
# {'_id': 3282, 'genres': 'Comedy', 'title': 'Different for Girls (1996)'}
# {'_id': 3286, 'genres': 'Comedy', 'title': 'Snow Day (2000)'}
# {'_id': 3290, 'genres': 'Comedy', 'title': 'Soft Toilet Seats (1999)'}
# {'_id': 3302, 'genres': 'Comedy', 'title': 'Beautiful People (1999)'}
# {'_id': 3313, 'genres': 'Comedy', 'title': 'Class Reunion (1982)'}
# {'_id': 3321, 'genres': 'Comedy', 'title': 'Waiting Game, The (2000)'}
# {'_id': 3322, 'genres': 'Comedy', 'title': '3 Strikes (2000)'}
# {'_id': 3324, 'genres': 'Comedy', 'title': 'Drowning Mona (2000)'}
# {'_id': 3306, 'genres': 'Comedy', 'title': 'Circus, The (1928)'}
# {'_id': 3309, 'genres': 'Comedy', 'title': "Dog's Life, A (1920)"}
# {'_id': 3341, 'genres': 'Comedy', 'title': 'Born Yesterday (1950)'}
# {'_id': 3349, 'genres': 'Comedy', 'title': 'Perils of Pauline, The (1947)'}
# {'_id': 3361, 'genres': 'Comedy', 'title': 'Bull Durham (1988)'}
# {'_id': 3385, 'genres': 'Comedy', 'title': 'Volunteers (1985)'}
# {'_id': 3388, 'genres': 'Comedy', 'title': 'Harry and the Hendersons (1987)'}
# {'_id': 3387, 'genres': 'Comedy', 'title': "Who's Harry Crumb? (1989)"}
# {'_id': 3391, 'genres': 'Comedy', 'title': "Who's That Girl? (1987)"}
# {'_id': 3392, 'genres': 'Comedy', 'title': 'She-Devil (1989)'}
# {'_id': 3395, 'genres': 'Comedy', 'title': 'Nadine (1987)'}
# {'_id': 3421, 'genres': 'Comedy', 'title': 'Animal House (1978)'}
# {'_id': 3450, 'genres': 'Comedy', 'title': 'Grumpy Old Men (1993)'}
# {'_id': 3460,
#  'genres': 'Comedy',
#  'title': 'Hillbillys in a Haunted House (1967)'}
# {'_id': 3462, 'genres': 'Comedy', 'title': 'Modern Times (1936)'}
# {'_id': 3446, 'genres': 'Comedy', 'title': 'Funny Bones (1995)'}
# {'_id': 3463, 'genres': 'Comedy', 'title': 'Last Resort (1994)'}
# {'_id': 3473,
#  'genres': 'Comedy',
#  'title': 'Jonah Who Will Be 25 in the Year 2000 (1976)'}
# {'_id': 3481, 'genres': 'Comedy', 'title': 'High Fidelity (2000)'}
# {'_id': 3497, 'genres': 'Comedy', 'title': 'Max Dugan Returns (1983)'}
# {'_id': 3491, 'genres': 'Comedy', 'title': 'My Chauffeur (1986)'}
# {'_id': 3507, 'genres': 'Comedy', 'title': 'Odd Couple, The (1968)'}
# {'_id': 3515, 'genres': 'Comedy', 'title': 'Me Myself I (2000)'}
# {'_id': 3511, 'genres': 'Comedy', 'title': 'Ready to Rumble (2000)'}
# {'_id': 3520, 'genres': 'Comedy', 'title': 'How to Stuff a Wild Bikini (1965)'}
# {'_id': 3525, 'genres': 'Comedy', 'title': 'Bachelor Party (1984)'}
# {'_id': 3530, 'genres': 'Comedy', 'title': 'Smoking/No Smoking (1993)'}
# {'_id': 3532,
#  'genres': 'Comedy',
#  'title': 'Freedom for Us (� nous la libert� ) (1931)'}
# {'_id': 3534, 'genres': 'Comedy', 'title': '28 Days (2000)'}
# {'_id': 3538, 'genres': 'Comedy', 'title': 'East is East (1999)'}
# {'_id': 3544, 'genres': 'Comedy', 'title': 'Shakes the Clown (1991)'}
# {'_id': 3552, 'genres': 'Comedy', 'title': 'Caddyshack (1980)'}
# {'_id': 3567, 'genres': 'Comedy', 'title': 'Bossa Nova (1999)'}
# {'_id': 3590, 'genres': 'Comedy', 'title': 'Lords of Flatbush, The (1974)'}
# {'_id': 3595, 'genres': 'Comedy', 'title': 'Held Up (2000)'}
# {'_id': 3596, 'genres': 'Comedy', 'title': 'Screwed (2000)'}
# {'_id': 3613, 'genres': 'Comedy', 'title': 'Things Change (1988)'}
# {'_id': 3608, 'genres': 'Comedy', 'title': "Pee-wee's Big Adventure (1985)"}
# {'_id': 3617, 'genres': 'Comedy', 'title': 'Road Trip (2000)'}
# {'_id': 3618, 'genres': 'Comedy', 'title': 'Small Time Crooks (2000)'}
# {'_id': 3619, 'genres': 'Comedy', 'title': 'Hollywood Knights, The (1980)'}
# {'_id': 3622, 'genres': 'Comedy', 'title': 'Twelve Chairs, The (1970)'}
# {'_id': 3626, 'genres': 'Comedy', 'title': '8 1/2 Women (1999)'}
# {'_id': 3603, 'genres': 'Comedy', 'title': 'Gay Deceivers, The (1969)'}
# {'_id': 3597, 'genres': 'Comedy', 'title': 'Whipped (2000)'}
# {'_id': 3629, 'genres': 'Comedy', 'title': 'Gold Rush, The (1925)'}
# {'_id': 3631, 'genres': 'Comedy', 'title': "It's in the Water (1998)"}
# {'_id': 3632, 'genres': 'Comedy', 'title': 'Monsieur Verdoux (1947)'}
# {'_id': 3646, 'genres': 'Comedy', 'title': "Big Momma's House (2000)"}
# {'_id': 3669, 'genres': 'Comedy', 'title': 'Stay Tuned (1992)'}
# {'_id': 3690, 'genres': 'Comedy', 'title': "Porky's Revenge (1985)"}
# {'_id': 3688, 'genres': 'Comedy', 'title': "Porky's (1981)"}
# {'_id': 3689, 'genres': 'Comedy', 'title': "Porky's II: The Next Day (1983)"}
# {'_id': 3691, 'genres': 'Comedy', 'title': 'Private School (1983)'}
# {'_id': 3712, 'genres': 'Comedy', 'title': 'Soapdish (1991)'}
# {'_id': 3715, 'genres': 'Comedy', 'title': 'Burglar (1987)'}
# {'_id': 3722, 'genres': 'Comedy', 'title': 'Live Virgin (1999)'}
# {'_id': 3721, 'genres': 'Comedy', 'title': 'Trixie (1999)'}
# {'_id': 3752, 'genres': 'Comedy', 'title': 'Me, Myself and Irene (2000)'}
# {'_id': 3760, 'genres': 'Comedy', 'title': 'Kentucky Fried Movie, The (1977)'}
# {'_id': 3773, 'genres': 'Comedy', 'title': 'House Party (1990)'}
# {'_id': 3774, 'genres': 'Comedy', 'title': 'House Party 2 (1991)'}
# {'_id': 3804, 'genres': 'Comedy', 'title': 'H.O.T.S. (1979)'}
# {'_id': 3786, 'genres': 'Comedy', 'title': "But I'm a Cheerleader (1999)"}
# {'_id': 3784, 'genres': 'Comedy', 'title': 'Kid, The (2000)'}
# {'_id': 3787, 'genres': 'Comedy', 'title': 'Shower (Xizhao) (1999)'}
# {'_id': 3809, 'genres': 'Comedy', 'title': 'What About Bob? (1991)'}
# {'_id': 3812,
#  'genres': 'Comedy',
#  'title': 'Everything You Always Wanted to Know About Sex (1972)'}
# {'_id': 3814, 'genres': 'Comedy', 'title': 'Love and Death (1975)'}
# {'_id': 3819, 'genres': 'Comedy', 'title': 'Tampopo (1986)'}
# {'_id': 3821,
#  'genres': 'Comedy',
#  'title': 'Nutty Professor II: The Klumps (2000)'}
# {'_id': 3846, 'genres': 'Comedy', 'title': 'Easy Money (1983)'}
# {'_id': 3831, 'genres': 'Comedy', 'title': 'Saving Grace (2000)'}
# {'_id': 3828, 'genres': 'Comedy', 'title': 'Better Living (1998)'}
# {'_id': 3852, 'genres': 'Comedy', 'title': 'Tao of Steve, The (2000)'}
# {'_id': 3851, 'genres': 'Comedy', 'title': "I'm the One That I Want (2000)"}
# {'_id': 3866, 'genres': 'Comedy', 'title': 'Sunset Strip (2000)'}
# {'_id': 3868,
#  'genres': 'Comedy',
#  'title': 'Naked Gun: From the Files of Police Squad!, The (1988)'}
# {'_id': 3861, 'genres': 'Comedy', 'title': 'Replacements, The (2000)'}
# {'_id': 3858, 'genres': 'Comedy', 'title': 'Cecil B. Demented (2000)'}
# {'_id': 3869,
#  'genres': 'Comedy',
#  'title': 'Naked Gun 2 1/2: The Smell of Fear, The (1991)'}
# {'_id': 3862, 'genres': 'Comedy', 'title': 'About Adam (2000)'}
# {'_id': 3882, 'genres': 'Comedy', 'title': 'Bring It On (2000)'}
# {'_id': 3899, 'genres': 'Comedy', 'title': 'Circus (2000)'}
# {'_id': 3905, 'genres': 'Comedy', 'title': 'Specials, The (2000)'}
# {'_id': 3884, 'genres': 'Comedy', 'title': 'Crew, The (2000)'}
# {'_id': 3921, 'genres': 'Comedy', 'title': 'Beach Party (1963)'}
# {'_id': 3922, 'genres': 'Comedy', 'title': 'Bikini Beach (1964)'}
# {'_id': 3924, 'genres': 'Comedy', 'title': 'Pajama Party (1964)'}
# {'_id': 3925, 'genres': 'Comedy', 'title': 'Stranger Than Paradise (1984)'}
# {'_id': 3929, 'genres': 'Comedy', 'title': 'Bank Dick, The (1940)'}
# {'_id': 3943, 'genres': 'Comedy', 'title': 'Bamboozled (2000)'}
# {'_id': 3948, 'genres': 'Comedy', 'title': 'Meet the Parents (2000)'}
# {'_id': 3911, 'genres': 'Comedy', 'title': 'Best in Show (2000)'}

# %% [markdown]
# **Q** : Fetch and display the `name` and `occupation` for Clifford Johnathan. The second paramater for `find()` ([doc here](https://api.mongodb.com/python/current/api/pymongo/collection.html#pymongo.collection.Collection.find)) is called the `projection` and is used to limit which data to fetch from the query.

# %%
users = db.users
users = users.find({"name": "Clifford Johnathan"}, {"occupation":1})
for user in users:
    print(user.get("occupation"))
#users
# Out:
# technician/engineer

# %% [markdown]
# **Q**: How many minors (by `age`) have rated movies ?

# %%
users = db.users.find({"age": {"$lt": 18}})
# print(len(users["movies"]))
#print(len(users))

#pprint(users)
cont=0
for user in users:
    # pprint(user)
    rated_count = 0
    for movie in user["movies"]:
        if movie["rating"]:
            rated_count+=1
    if rated_count == len(user["movies"]):    
        cont+=1
    #pprint(user)
pprint(cont)
# “age”:{"$lt”:18}
# Out:
# 222

# %% [markdown]
# **Q**: Display science fiction movies ('Sci-Fi') and suspense movies ('Thriller'). This time you need to use a regex to parse genres and look for those values.

# %%
movies = db.movies
movies = movies.collectionname.find({'genres':{'$regex':'*Sci-Fi|Thriller^'}})
movies
#for movie in movies:
#    pprint(movie)

# %% [markdown]
# §**Q**: If we want more advanced textual search, we need a particular index. Use the `create_index()` method to index as [TEXT](https://docs.mongodb.com/manual/core/index-text/) the `genres` field of the `movies` collection.

# %% [markdown]
# **Q**: Restart the search for science fiction and thriller movies with the operator `$text`

# %% [markdown]
# **Q**: Display the first 30 movies (`limit`) in alphabetical order (`sort`) by title

# %% [markdown]
# **Q**: How many users have seen the movie "Star Wars: Episode V - The Empire Strikes Back (1980)" (`_id 1196`) ? The `movies` argument is an array so we should try the [elemMatch](https://docs.mongodb.com/manual/reference/operator/projection/elemMatch/) operator here.

# %% [markdown]
# **Q**: And how many gave it a rating of 1 or 2 ?

# %% [markdown]
# ### Updating data

# %% [markdown]
# **Q**: Insert a new user with the properties `name`, `gender` ('M' or'F'), `occupation` and `age`, using the `insert_one()` command. Display it with `find_one()`.

# %% [markdown]
# **Q**: Add an appreciation on a viewed movie with `update_one()`, add the movies property containing a table with a document (`movieid`, `rating`, `timestamp` with the value `datetime.datetime.utcnow()`).
#
# You will need to read the documentation on [update operators](https://docs.mongodb.org/manual/reference/operator/update/).

# %% [markdown]
# **Q**: Find the number of users who have declared a `programmer` occupation. Modify them so that they are `developer`. Verify your update.

# %% [markdown]
# ## II. Modelling a blog
#
# We will now model a blog using Mongo.
#
# First, switch to a new `Blog` database. Each blog post will have the following arguments:
#
# * The author (author field, string type)
# * The date (date field, string type in YYYY-MM-DD format)
# * The content (field content)
# * Tags (field tags, a string array)
# * A list of comments (field comments) containing:
#  * The author (author field, string type)
#  * The date (date field, string type in YYYY-MM-DD format)
#  * The content (field content)

# %% [markdown]
# **Q**: Create a first post by `rick`, on January 15th, with the tags `mongodb` and `nosql`.

# %% [markdown]
# **Q**: Create a second post by `kate`, on January 21, with the tag `nosql` and a comment from `rick` on the same day.

# %% [markdown]
# **Q**: Display the author of the last post with the tag `nosql`

# %% [markdown]
# **Q**: Add a comment by `jack` on January 25, to `kate`'s post

# %% [markdown]
# **Q**: Display all comments by `kate`

# %% [markdown]
# ## Postquisites

# %%
# !mongo test_database --eval 'db.dropDatabase()'
# Out:
# MongoDB shell version v4.4.1
# connecting to: mongodb://127.0.0.1:27017/test_database?compressors=disabled&gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("57ebf7ea-8f73-4d51-a7b2-f79458f28451") }
# MongoDB server version: 4.4.1
# { "dropped" : "test_database", "ok" : 1 }

# %%
# !mongo MovieLens --eval 'db.dropDatabase()'
# Out:
# MongoDB shell version v4.4.1
# connecting to: mongodb://127.0.0.1:27017/MovieLens?compressors=disabled&gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("8a2bd98e-7afd-449c-a819-26fe21fa025f") }
# MongoDB server version: 4.4.1
# { "dropped" : "MovieLens", "ok" : 1 }

# %%
# !mongo Blog --eval 'db.dropDatabase()'
# Out:
# MongoDB shell version v4.4.1
# connecting to: mongodb://127.0.0.1:27017/Blog?compressors=disabled&gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("044feb98-d239-43b1-9269-bc7913b0d9d8") }
# MongoDB server version: 4.4.1
# { "ok" : 1 }
